# %%
import FlowSight as fs
from importlib import reload
fs = reload(fs)
fs.dataset = reload(fs.dataset)
fs.plot = reload(fs.plot)

# %%
datasets = {"sorted tomato": "Tomato sorted.txt"}
df = fs.dataset.load(datasets)
adata = fs.dataset.to_adata(df, used_channels=["Ch1", "Ch4", "Ch6"])
adata = fs.plot.PCA(adata)
# Out:
# AnnData expects .obs.index to contain strings, but your first indices are: Int64Index([0, 1], dtype='int64', name='Object Number'), …
# AnnData expects .obs.index to contain strings, but your first indices are: Int64Index([0, 1], dtype='int64', name='Object Number'), …
# Transforming to str index.
# ... storing 'experiment' as categorical

# %%
adata = fs.plot.cluster(adata, n_pcs=6, n_neighbors=20, resolution=0.3)
# Out:
# C:\Users\jetja\AppData\Roaming\Python\Python36\site-packages\umap\spectral.py:229: UserWarning: Embedding a total of 2 separate connected components using meta-embedding (experimental)
#   n_components

# %%
fs.plot.plot_group(adata, groupby="leiden", group="2", n_img=20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-87c472483ede> in <module>()
# ----> 1 fs.plot.plot_group(adata, groupby="leiden", group="2", n_img=20)
#
# c:\users\jetja\onedrive\dokument\projekt\flowsight\FlowSight\plot.py in plot_group(adata, groupby, group, n_img)
#      51     for row in df.iterrows():
#      52         files = [row[1].Ch1, row[1].Ch4 ,row[1].Ch6]
# ---> 53         im.append(tifffile.imread(files))
#      54     i=1
#      55     plt.figure(figsize=(8, n_img*1), facecolor='black')
#
# ~\AppData\Roaming\Python\Python36\site-packages\tifffile\tifffile.py in imread(files, **kwargs)
#     590
#     591     with TiffSequence(files, **kwargs_seq) as imseq:
# --> 592         return imseq.asarray(**kwargs)
#     593
#     594
#
# ~\AppData\Roaming\Python\Python36\site-packages\tifffile\tifffile.py in asarray(self, file, ioworkers, out, **kwargs)
#    6178             return self.fromfile(file, **kwargs)
#    6179
# -> 6180         im = self.fromfile(self.files[0], **kwargs)
#    6181         shape = self.shape + im.shape
#    6182         result = create_output(out, shape, dtype=im.dtype)
#
# ~\AppData\Roaming\Python\Python36\site-packages\tifffile\tifffile.py in imread(files, **kwargs)
#     586
#     587         if isinstance(files, str) or hasattr(files, 'seek'):
# --> 588             with TiffFile(files, **kwargs_file) as tif:
#     589                 return tif.asarray(**kwargs)
#     590
#
# ~\AppData\Roaming\Python\Python36\site-packages\tifffile\tifffile.py in __init__(self, arg, name, offset, size, multifile, _useframes, **kwargs)
#    2126                     raise TypeError(f'unexpected keyword argument: {key}')
#    2127
# -> 2128         fh = FileHandle(arg, mode='rb', name=name, offset=offset, size=size)
#    2129         self._fh = fh
#    2130         self._multifile = bool(multifile)
#
# ~\AppData\Roaming\Python\Python36\site-packages\tifffile\tifffile.py in __init__(self, file, mode, name, offset, size)
#    6284         self.is_file = False
#    6285         self._lock = NullContext()
# -> 6286         self.open()
#    6287
#    6288     def open(self):
#
# ~\AppData\Roaming\Python\Python36\site-packages\tifffile\tifffile.py in open(self)
#    6297             self._file = os.path.realpath(self._file)
#    6298             self._dir, self._name = os.path.split(self._file)
# -> 6299             self._fh = open(self._file, self._mode)
#    6300             self._close = True
#    6301             if self._offset is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\jetja\\OneDrive\\Dokument\\Projekt\\FlowSight\\test\\data\\tomato\\980_Ch1.ome.tif'
