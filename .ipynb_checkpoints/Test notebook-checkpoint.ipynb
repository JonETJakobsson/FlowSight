# %%
import FlowSight as fs
from importlib import reload
fs = reload(fs)
fs.dataset = reload(fs.dataset)
fs.plot = reload(fs.plot)

# %%
datasets = {"tomato": "tomato raw.txt"}
df = fs.dataset.load(datasets)
adata = fs.dataset.to_adata(df, used_channels=["Ch1", "Ch4", "Ch6"])
adata = fs.plot.PCA(adata)
# Out:
# AnnData expects .obs.index to contain strings, but your first indices are: Int64Index([0, 1], dtype='int64', name='Object Number'), …
# AnnData expects .obs.index to contain strings, but your first indices are: Int64Index([0, 1], dtype='int64', name='Object Number'), …
# Transforming to str index.
# ... storing 'experiment' as categorical

# %%
adata = fs.plot.cluster(adata, n_pcs=5, n_neighbors=10, resolution=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-0fa4b3b6af87> in <module>()
# ----> 1 adata = fs.plot.cluster(adata, n_pcs=5, n_neighbors=10, resolution=0.5)
#
# ~\OneDrive\Dokument\Projekt\FlowSight\FlowSight\plot.py in cluster(adata, n_pcs, n_neighbors, resolution)
#      23
#      24         # Create a KNN graph
# ---> 25         sc.pp.neighbors(adata, n_pcs=n_pcs, n_neighbors=n_neighbors)
#      26
#      27         # Detect clusters using Leiden algorithm
#
# NameError: name 'sc' is not defined
